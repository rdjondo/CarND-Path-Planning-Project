# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../build/trajectory_calc.csv')
print(df.describe())
# Out:
#              s_req            s            x            y
# count   800.000000   800.000000   800.000000   800.000000
# mean   3995.000000  3083.401001  1286.129786  1979.766163
# std    2310.844002  2122.228690   734.175263   740.098694
# min       0.000000     0.000000   155.516000  1128.720000
# 25%    1997.500000   998.621000   592.553000  1182.435000
# 50%    3995.000000  2945.000000  1307.285000  1886.820000
# 75%    5992.500000  4942.500000  2033.137500  2842.835000
# max    7990.000000  6940.000000  2339.490000  3005.900000

# %%
x = df.x.values
y = df.y.values

import matplotlib.pyplot as plt

fig = plt.figure()

plt.plot( x[680:720],  y[680:720], '.')

plt.show()

# %%
print(df.iloc[690:700])
# Out:
#      s_req           s        x        y
# 690   6900  6900.00000  738.401  1131.88
# 691   6910  6910.00000  748.585  1130.76
# 692   6920  6920.00000  758.694  1130.10
# 693   6930  6930.00000  768.727  1129.78
# 694   6940  6940.00000  778.840  1129.64
# 695   6950     4.48415  788.925  1129.45
# 696   6960    14.48410  798.943  1129.20
# 697   6970    24.48410  808.985  1129.01
# 698   6980    34.48410  819.046  1128.90
# 699   6990    44.48410  829.084  1128.89

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
dist = np.sqrt(np.diff(x)**2+np.diff(y)**2)
plt.plot( dist[600:780], '-')

plt.show()
